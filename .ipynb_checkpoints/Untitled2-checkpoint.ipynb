# %%
import pandas as pd
df=pd.read_csv("emp.csv",skiprows=5,nrows=5,names=["eno","ename","salary","deptno","doj"])

# %%
#alternate way
df1=pd.read_csv("emp.csv")
df1[5:10]
# Out:
#    eno   ename  salary  deptno         doj
# 5    6   Smith    1000      10  2016-12-01
# 6    7  Robert    3000      20  2023-06-25
# 7    3    Nick    1000      30  2015-09-15
# 8    9   Naman    4000      30  2020-01-20
# 9    1   Vikas    1000      30  2017-10-03

# %%
import pandas as pd
df1 = pd.read_csv("emp.csv", header=None)
df1[1:5]
# Out:
#     0       1     2   3           4
# 1  10   Amber  1000  10  2018-05-14
# 2   2    Amar  1000  10  2017-03-22
# 3   8   Sagar  1000  20  2020-11-30
# 4   4  Thomas  1000  10  2019-08-18

# %%
for chn in pd.read_csv("emp.csv",chunksize=3):
    print(chn)
# Out:
#    eno  ename  salary  deptno         doj
# 0   10  Amber    1000      10  2018-05-14
# 1    2   Amar    1000      10  2017-03-22
# 2    8  Sagar    1000      20  2020-11-30
#    eno   ename  salary  deptno         doj
# 3    4  Thomas    1000      10  2019-08-18
# 4    5    Jade    2000      10  2021-02-10
# 5    6   Smith    1000      10  2016-12-01
#    eno   ename  salary  deptno         doj
# 6    7  Robert    3000      20  2023-06-25
# 7    3    Nick    1000      30  2015-09-15
# 8    9   Naman    4000      30  2020-01-20
#     eno   ename  salary  deptno         doj
# 9     1   Vikas    1000      30  2017-10-03
# 10   11  Dennis   41000      30  2024-01-05
# 11   12   Karan    2200      20  2018-06-16
#     eno   ename  salary  deptno         doj
# 12   13  Simran    1500      10  2019-12-19
# 13   14    Amit    2000      30  2022-04-09
# 14   15    Neha    1700      20  2021-07-22
#     eno  ename  salary  deptno         doj
# 15   16  Rahul    1200      10  2016-03-28

# %%
df.columns
# Out:
# Index(['eno', 'ename', 'salary', 'deptno', 'doj'], dtype='object')

# %%
df.dtypes
# Out:
# eno        int64
# ename     object
# salary     int64
# deptno     int64
# doj       object
# dtype: object

# %%
df=pd.read_csv('emp.csv',parse_dates=['doj'])
df.dtypes
df['doj'].dt.day
# Out:
# 0     14
# 1     22
# 2     30
# 3     18
# 4     10
# 5      1
# 6     25
# 7     15
# 8     20
# 9      3
# 10     5
# 11    16
# 12    19
# 13     9
# 14    22
# 15    28
# Name: doj, dtype: int32

# %%
df=pd.read_csv("emp.csv")
df.iloc[1:3]
# Out:
#    eno  ename  salary  deptno         doj
# 1    2   Amar    1000      10  2017-03-22
# 2    8  Sagar    1000      20  2020-11-30

# %%
df=pd.read_csv("emp.csv",header=2)
df[3:5]
# Out:
#    2    Amar  1000  10  2017-03-22
# 3  6   Smith  1000  10  2016-12-01
# 4  7  Robert  3000  20  2023-06-25

# %%
df=pd.read_json("tes.json")
df
# Out:
#                  name          language                id  \
# 0       Adeel Solangi            Sindhi  V59OF92YF627HFY0
# 1       Afzal Ghaffar            Sindhi  ENTOCR13RSCLZ6KU
# 2       Aamir Solangi            Sindhi  IAKPO3R4761JDRVG
# 3       Abla Dilmurat            Uyghur  5ZVOEPMJUI4MB4EN
# 4            Adil Eli            Uyghur  6VTI8X6LL0MMPJCC
# 5         Adile Qadir            Uyghur  F2KEU5L7EHYSYFTT
# 6   Abdukerim Ibrahim            Uyghur  LO6DVTZLRK68528I
# 7           Adil Abro            Sindhi  LJRIULRNJFCNZJAJ
# 8    Afonso Vilarchán          Galician  JMCL0CXNXHPL1GBC
# 9       Mark Schembri           Maltese  KU4T500C830697CW
# 10      Antía Sixirei          Galician  XOF91ZR7MHV1TXRS
# 11     Aygul Mutellip            Uyghur  FTSNV411G5MKLPDT
# 12       Awais Shaikh            Sindhi  OJMWMEEQWMLDU29P
# 13      Ambreen Ahmed            Sindhi  5G646V7E6TJW8X2M
# 14        Celtia Anes          Galician  Z53AJY7WUYPLAWC9
# ...

# %%
df=pd.read_csv("emp.csv")
df['newsalary']=df['salary']+10000
df
# Out:
#     eno   ename  salary  deptno         doj  newsalary
# 0    10   Amber    1000      10  2018-05-14      11000
# 1     2    Amar    1000      10  2017-03-22      11000
# 2     8   Sagar    1000      20  2020-11-30      11000
# 3     4  Thomas    1000      10  2019-08-18      11000
# 4     5    Jade    2000      10  2021-02-10      12000
# 5     6   Smith    1000      10  2016-12-01      11000
# 6     7  Robert    3000      20  2023-06-25      13000
# 7     3    Nick    1000      30  2015-09-15      11000
# 8     9   Naman    4000      30  2020-01-20      14000
# 9     1   Vikas    1000      30  2017-10-03      11000
# 10   11  Dennis   41000      30  2024-01-05      51000
# 11   12   Karan    2200      20  2018-06-16      12200
# 12   13  Simran    1500      10  2019-12-19      11500
# 13   14    Amit    2000      30  2022-04-09      12000
# 14   15    Neha    1700      20  2021-07-22      11700
# 15   16   Rahul    1200      10  2016-03-28      11200

# %%
df=pd.read_csv("emp.csv")
df
# Out:
#     eno   ename  salary  deptno         doj
# 0    10   Amber    1000      10  2018-05-14
# 1     2    Amar    1000      10  2017-03-22
# 2     8   Sagar    1000      20  2020-11-30
# 3     4  Thomas    1000      10  2019-08-18
# 4     5    Jade    2000      10  2021-02-10
# 5     6   Smith    1000      10  2016-12-01
# 6     7  Robert    3000      20  2023-06-25
# 7     3    Nick    1000      30  2015-09-15
# 8     9   Naman    4000      30  2020-01-20
# 9     1   Vikas    1000      30  2017-10-03
# 10   11  Dennis   41000      30  2024-01-05
# 11   12   Karan    2200      20  2018-06-16
# 12   13  Simran    1500      10  2019-12-19
# 13   14    Amit    2000      30  2022-04-09
# 14   15    Neha    1700      20  2021-07-22
# 15   16   Rahul    1200      10  2016-03-28
